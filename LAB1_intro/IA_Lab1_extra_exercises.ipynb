# %% [markdown]
# Es 1
#
# Write a program that asks the user for the base and height of
# a rectangle. Then print the perimeter and area value
# of the rectangle.

# %%
# compute_perimeter (b, h) function that receives two parameters (base, height) in input and compute the perimeter
def compute_perimeter (b, h):
  perimeter = 2*b + 2*h
  return perimeter

# computer_area (b, h) function that receives two parameters (base, height) in input and computer the area
def computer_area (b, h):
  area = b*h
  return area

# write the instructions to receive in input base and height and call the functions
b = float(input('Base: '))         #base = eval(base)
h = float(input('Height: '))

print('Perimeter = ' + str(compute_perimeter(b,h)))
print('Area = ' + str(computer_area (b, h)))
# Out:
# Base: 4
# Height: 3
# Perimeter = 14.0
# Area = 12.0

# %% [markdown]
# Es 2
#
# s = input("What is your name? ")
#
# Print the type of the variable s, the length, the first and last character.

# %%
s = input("What is your name? ")

#Print the type of the variable s,
print(type(s))

#the length,
print(len(s))

#the first and last character.
print(s[0],  s[len(s) - 1])
# Out:
# What is your name? Lorenzo Karol
# <class 'str'>
# 13
# L l

# %% [markdown]
# Es 3
#
# Write a program that asks for two numbers. If the sum of the two
# number exceeds 100, print ``Number too large''

# %%
# ask number x
x = float(input('x = '))

# ask number y
y = float(input('y = '))

# compute the sum
sum = x + y
print(sum)

# verify the condition and add print
if sum >100:
  print('Number too large')
# Out:
# x = 53
# y = 56
# 109.0
# Number too large

# %% [markdown]
# Es 4
# *   Fill an initially empty list with 10 values ​​read from keyboard.
# *   Print the largest and smallest value contained in the list

# %%
# Empty list
l = []

# Iterate
for i in range (0, 10):

# Ask for value
  val = int(input('insert number ' + str(i) + ': '))

# Fill
  l.append(val)

# Temp max
temp_max = 0

# Temp min
temp_min = 0

# Iterate and check which is the max and the min
for i in range(len(l)):
  if l[i] > temp_max:
    temp_max = l[i]
  if l[i] < temp_min:
    temp_min = l[i]

print('\n' + str(l) + '\n')
print('max =' + str(temp_max) + '\n'
      'min =' + str(temp_min))
# Out:
# insert number 0: 5
# insert number 1: 3
# insert number 2: 6
# insert number 3: 64
# insert number 4: 5
# insert number 5: 8
# insert number 6: 6
# insert number 7: -46
# insert number 8: 7
# insert number 9: 4
# [5, 3, 6, 64, 5, 8, 6, -46, 7, 4]
#
# max =64
# min =-46

# %% [markdown]
# Es 5
#
# After importing the numpy module create an array
# of 100 random numbers with integer values ​​between 0 and
# 50.
#
# Print all numbers greater than the mean and the
# their location
#
# NB: You find hints in the documentation

# %%
# import the numpy
import numpy as np

# create an array of 100 random numbers between 0 and 50
random_numbers = np.random.randint(0, 51, 100)
print(random_numbers)

# compute the mean
E = np.mean(random_numbers)

# Print the expected number and the locations
print('mean = ' + str(E) + '\n')
greater_than_mean = np.where(random_numbers > E)
for i in greater_than_mean[0]:
  print('item\t' + str(random_numbers[i]) + ' in position ' + str(i))
# Out:
# [ 0 45  3 23 28 36 22 46 14  1 46 30 10 44 36  5 18 40 17 42 47 45 18 23
#  32 14 23 26 50 39 35 34 41 49 43 37 23 25 49 47 18  0  6 11 49  5 31 13
#  13 46  4 35 33 32 50 38 39 23 17 16 14 22 26 31 31 43 35 41 17 15 45  4
#  16 43 29  4 19 38 40 25  3  3  2 32 47 47 46  0 24 29 23 12 49 50 11 43
#  24 10 30  8]
# mean = 27.16
#
# item	45 in position 1
# item	28 in position 4
# item	36 in position 5
# item	46 in position 7
# item	46 in position 10
# item	30 in position 11
# item	44 in position 13
# item	36 in position 14
# item	40 in position 17
# item	42 in position 19
# item	47 in position 20
# item	45 in position 21
# item	32 in position 24
# item	50 in position 28
# item	39 in position 29
# item	35 in position 30
# item	34 in position 31
# item	41 in position 32
# item	49 in position 33
# item	43 in position 34
# item	37 in position 35
# item	49 in position 38
# item	47 in position 39
# item	49 in position 44
# item	31 in position 46
# item	46 in position 49
# item	35 in position 51
# item	33 in position 52
# item	32 in position 53
# item	50 in position 54
# item	38 in position 55
# item	39 in position 56
# item	31 in position 63
# item	31 in position 64
# item	43 in position 65
# item	35 in position 66
# item	41 in position 67
# item	45 in position 70
# item	43 in position 73
# item	29 in position 74
# item	38 in position 77
# item	40 in position 78
# item	32 in position 83
# item	47 in position 84
# item	47 in position 85
# item	46 in position 86
# item	29 in position 89
# item	49 in position 92
# item	50 in position 93
# item	43 in position 95
# item	30 in position 98

# %% [markdown]
# Es 6
#
# Write a multiplier function(number_list) that
# given a list of numbers, multiply all of them together and returns the result. If the
# list is empty returns 0.

# %%
# define the function
def multiplier(l):
  tot = 1
# check if it is empty
  if len(l) == 0:
    tot = 0
# multiple the values
  for i in l:
    tot *= i
  return tot

# define the list
l = [5,2,7,4]

# call the function
print(multiplier(l))
# Out:
# 280

# %% [markdown]
# Es 7
#
# Write a countdown(string) function.
# The function takes a string as a parameter and returns the reversed
# string after making it lowercase all the
# characters and in uppercase only the last character (e.g
# example "abcd" becomes "dcbA"). Also manage the
# empty string case.

# %%
def countdown(string):
  s = ''
  if len(string) == 0:
    return s
  s += string[0].upper()
  s += string[1:len(string)].lower()
  return s[::-1]

s = 'abcd'
print('original string: ' + s)
print('modified string: ' + countdown(s))
# Out:
# original string: abcd
# modified string: dcbA

# %% [markdown]
# Es 8
#
# Write a function frequency(string). The function
# takes a string as a parameter and returns a
# dictionary representing the frequency of each
# character component of the string.
# For example, given a string "ababcc", the
# function returns result {"a": 2, "b": 2, "c":
# 2}.

# %%
def frequency(string):
  d = dict()
  for i in string:
    if i in d:
      d[i] += 1
    else:
      d[i] = 1
  return d

s = "ababcc"
print('original string: ' + s)
print('frequency function output: ' + str(frequency(s)))
# Out:
# original string: ababcc
# frequenzy function output: {'a': 2, 'b': 2, 'c': 2}
